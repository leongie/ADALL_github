# %% [markdown]
# <a href="https://colab.research.google.com/github/leongie/ADALL_github/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i want print ('hello world again')
# Out:
# hello world again

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example: Replace this with the raw URL of your GitHub file
github_raw_url = 'https://raw.githubusercontent.com/leongie/ADALL_github/refs/heads/main/laptop_prices_2024_sgd_TL.csv'
try:
 df = pd.read_csv(github_raw_url)
 print("Successfully loaded data from GitHub!")
 display(df.head())

 #print each df col graph
 for col in df.columns:
  plt.plot(df.index, df[col])
  plt.xlabel('Index')
  plt.ylabel(col)
  plt.title(f'{col} vs Index')
  plt.show()

except Exception as e:
 print(f"Error loading data: {e}")
 print("Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.")

 #try and except block - if there is an error, print something more readable , e is the error message

  #windsurf prompt is within the code
  #usually gemini is create new line of code

  #what does one row represent and what is the target variable?
  # each row - information of each laptop
  # target variable is the price in this data- there is only target variable - either , numerical (what is the price) or categorical ( will this person pay his/her bills on time / pass fail/ resign or not resign)
  # must be very clear what you are predicting  - if it is categorical, cannot use linear regression
  #
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Model             1000 non-null   object
#  2   CPU               1000 non-null   object
#  3   GPU               1000 non-null   object
#  4   RAM_GB            1000 non-null   int64
#  5   Storage_Type      1000 non-null   object
#  6   Storage_GB        1000 non-null   int64
#  7   Touchscreen       1000 non-null   bool
#  8   Weight_kg         1000 non-null   float64
#  9   Screen_Size_inch  1000 non-null   float64
#  10  Discount_percent  1000 non-null   float64
#  11  Price_SGD         1000 non-null   float64
#  12  Brand_Discount    1000 non-null   int64
#  13  Member_Discount   1000 non-null   float64
# dtypes: bool(1), float64(5), int64(3), object(5)
# memory usage: 102.7+ KB
# None

# %%
display(df.describe())
# Out:
#             RAM_GB   Storage_GB    Weight_kg  Screen_Size_inch  \
# count  1000.000000  1000.000000  1000.000000       1000.000000
# mean     53.128000  1505.024000     2.036560         15.645700
# std      44.413288  1380.203919     0.746477          1.759846
# min       8.000000   256.000000     1.000000         13.300000
# 25%      16.000000   512.000000     1.340000         14.000000
# 50%      32.000000  1024.000000     1.970000         15.600000
# 75%      64.000000  2048.000000     2.680000         17.300000
# max     128.000000  4096.000000     3.500000         18.400000
#
#        Discount_percent    Price_SGD  Brand_Discount  Member_Discount
# count       1000.000000  1000.000000       1000.0000      1000.000000
# mean           7.538230  2277.796410          6.7680       135.810660
# std            4.334012   616.496246          2.6346        41.344593
# min            0.000000   995.770000          3.0000        50.740000
# ...

# %%
display(df.head())
# Out:
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
#    Discount_percent  Price_SGD  Brand_Discount  Member_Discount
# ...

# %%
print(df.isnull().sum())
# Out:
# Brand               0
# Model               0
# CPU                 0
# GPU                 0
# RAM_GB              0
# Storage_Type        0
# Storage_GB          0
# Touchscreen         0
# Weight_kg           0
# Screen_Size_inch    0
# Discount_percent    0
# Price_SGD           0
# Brand_Discount      0
# Member_Discount     0
# dtype: int64
